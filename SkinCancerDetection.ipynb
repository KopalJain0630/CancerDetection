# %%
import os

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import seaborn as sns
from PIL import Image
np.random.seed(11) # It's my lucky number
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score
import itertools

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\kopal\anaconda\lib\site-packages (2.17.0)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.32.2)
# Requirement already satisfied: setuptools in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.67.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.6.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\kopal\anaconda\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\kopal\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\kopal\anaconda\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (13.3.5)
# Requirement already satisfied: namex in c:\users\kopal\anaconda\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\kopal\anaconda\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kopal\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kopal\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kopal\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kopal\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kopal\anaconda\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\kopal\anaconda\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\kopal\anaconda\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\kopal\anaconda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\kopal\anaconda\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kopal\anaconda\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kopal\anaconda\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.1.0)

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\kopal\anaconda\lib\site-packages (3.6.0)
# Requirement already satisfied: absl-py in c:\users\kopal\anaconda\lib\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\kopal\anaconda\lib\site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in c:\users\kopal\anaconda\lib\site-packages (from keras) (13.3.5)
# Requirement already satisfied: namex in c:\users\kopal\anaconda\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\kopal\anaconda\lib\site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in c:\users\kopal\anaconda\lib\site-packages (from keras) (0.13.0)
# Requirement already satisfied: ml-dtypes in c:\users\kopal\anaconda\lib\site-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in c:\users\kopal\anaconda\lib\site-packages (from keras) (23.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\kopal\anaconda\lib\site-packages (from optree->keras) (4.11.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\kopal\anaconda\lib\site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kopal\anaconda\lib\site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kopal\anaconda\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras) (0.1.0)

# %%
# !pip install scikeras
# Out:
# Requirement already satisfied: scikeras in c:\users\kopal\anaconda\lib\site-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in c:\users\kopal\anaconda\lib\site-packages (from scikeras) (3.6.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in c:\users\kopal\anaconda\lib\site-packages (from scikeras) (1.4.2)
# Requirement already satisfied: absl-py in c:\users\kopal\anaconda\lib\site-packages (from keras>=3.2.0->scikeras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\kopal\anaconda\lib\site-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in c:\users\kopal\anaconda\lib\site-packages (from keras>=3.2.0->scikeras) (13.3.5)
# Requirement already satisfied: namex in c:\users\kopal\anaconda\lib\site-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\kopal\anaconda\lib\site-packages (from keras>=3.2.0->scikeras) (3.11.0)
# Requirement already satisfied: optree in c:\users\kopal\anaconda\lib\site-packages (from keras>=3.2.0->scikeras) (0.13.0)
# Requirement already satisfied: ml-dtypes in c:\users\kopal\anaconda\lib\site-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in c:\users\kopal\anaconda\lib\site-packages (from keras>=3.2.0->scikeras) (23.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\kopal\anaconda\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kopal\anaconda\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kopal\anaconda\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (2.2.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\kopal\anaconda\lib\site-packages (from optree->keras>=3.2.0->scikeras) (4.11.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\kopal\anaconda\lib\site-packages (from rich->keras>=3.2.0->scikeras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kopal\anaconda\lib\site-packages (from rich->keras>=3.2.0->scikeras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kopal\anaconda\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.0)

# %%
import keras
from keras.utils import to_categorical # used for converting labels to one-hot-encoding
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras import backend as K
from keras.layers import BatchNormalization
from keras.utils import to_categorical # convert to one-hot-encoding
from keras.optimizers import Adam, RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from scikeras.wrappers import KerasClassifier
from keras.applications.resnet50 import ResNet50
from keras import backend as K

# %%
folder_benign_train = 'input/data/train/benign'
folder_malignant_train = 'input/data/train/malignant'

folder_benign_test = 'input/data/test/benign'
folder_malignant_test = 'input/data/test/malignant'

read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))

# Load in training pictures 
ims_benign = [read(os.path.join(folder_benign_train, filename)) for filename in os.listdir(folder_benign_train)]
X_benign = np.array(ims_benign, dtype='uint8')
ims_malignant = [read(os.path.join(folder_malignant_train, filename)) for filename in os.listdir(folder_malignant_train)]
X_malignant = np.array(ims_malignant, dtype='uint8')

# %%
ims_benign = [read(os.path.join(folder_benign_test, filename)) for filename in os.listdir(folder_benign_test)]
X_benign_test = np.array(ims_benign, dtype='uint8')
ims_malignant = [read(os.path.join(folder_malignant_test, filename)) for filename in os.listdir(folder_malignant_test)]
X_malignant_test = np.array(ims_malignant, dtype='uint8')

# Create labels
y_benign = np.zeros(X_benign.shape[0])
y_malignant = np.ones(X_malignant.shape[0])

y_benign_test = np.zeros(X_benign_test.shape[0])
y_malignant_test = np.ones(X_malignant_test.shape[0])

# %%
X_train = np.concatenate((X_benign, X_malignant), axis = 0)
y_train = np.concatenate((y_benign, y_malignant), axis = 0)

X_test = np.concatenate((X_benign_test, X_malignant_test), axis = 0)
y_test = np.concatenate((y_benign_test, y_malignant_test), axis = 0)

# Shuffle data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
y_train = y_train[s]

s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
y_test = y_test[s]

# %%
w=40
h=30
fig=plt.figure(figsize=(12, 8))
columns = 5
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if y_train[i] == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(X_train[i], interpolation='nearest')
plt.show()

# %%
y_train = to_categorical(y_train, num_classes= 2)
y_test = to_categorical(y_test, num_classes= 2)

# %%
X_train = X_train/255.
X_test = X_test/255.

# %%
def build(input_shape= (224,224,3), lr = 1e-3, num_classes= 2,
          init= 'normal', activ= 'relu', optim= 'adam'):
    model = Sequential()
    model.add(keras.Input(shape=input_shape)),
    model.add(Conv2D(64, kernel_size=(3, 3),padding = 'Same',
                     activation= activ, kernel_initializer='glorot_uniform'))
    model.add(MaxPool2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, kernel_size=(3, 3),padding = 'Same', 
                     activation =activ, kernel_initializer = 'glorot_uniform'))
    model.add(MaxPool2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer=init))
    model.add(Dense(num_classes, activation='softmax'))
    model.summary()

    if optim == 'rmsprop':
        optimizer = RMSprop(learning_rate=lr)

    else:
        optimizer = Adam(learning_rate=lr)

    model.compile(optimizer = optimizer ,loss = "binary_crossentropy", metrics=["accuracy"])
    return model

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=5, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=1e-7)

# %%
input_shape = (224,224,3)
lr = 1e-5
init = 'normal'
activ = 'relu'
optim = 'adam'
epochs = 50
batch_size = 64

model = build(lr=1e-5, init= init, activ= activ, optim=optim, input_shape= input_shape)

history = model.fit(X_train, y_train, validation_split=0.2,
                    epochs= epochs, batch_size= batch_size, verbose=0, 
                    callbacks=[learning_rate_reduction]
                   )
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 200704)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    25,690,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,729,218 (98.15 MB)
#  Trainable params: 25,729,218 (98.15 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-07.
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1e-07.

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss', 'learning_rate'])

# %%
K.clear_session()
del model
del history
# Out:
# WARNING:tensorflow:From C:\Users\kopal\anaconda\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %%
kfold = KFold(n_splits=3, shuffle=True, random_state=11)

cvscores = []

# %%
for train, test in kfold.split(X_train, y_train):
  # create model
    model = build(lr=lr, 
                  init= init, 
                  activ= activ, 
                  optim=optim, 
                  input_shape= input_shape)
    
    # Fit the model
    model.fit(X_train[train], y_train[train], epochs=epochs, batch_size=batch_size, verbose=0)
    # evaluate the model
    scores = model.evaluate(X_train[test], y_train[test], verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
    K.clear_session()
    del model
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 200704)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    25,690,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,729,218 (98.15 MB)
#  Trainable params: 25,729,218 (98.15 MB)
#  Non-trainable params: 0 (0.00 B)
# compile_metrics: 76.11%
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 200704)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    25,690,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,729,218 (98.15 MB)
#  Trainable params: 25,729,218 (98.15 MB)
#  Non-trainable params: 0 (0.00 B)
# compile_metrics: 69.06%
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 200704)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    25,690,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,729,218 (98.15 MB)
#  Trainable params: 25,729,218 (98.15 MB)
#  Non-trainable params: 0 (0.00 B)
# compile_metrics: 77.25%

# %%
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# 74.14% (+/- 3.62%)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='accuracy', 
                                            patience=5, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=1e-7)

# %%
model = build(lr=lr, 
              init= init, 
              activ= activ, 
              optim=optim, 
              input_shape= input_shape)

model.fit(X_train, y_train,
          epochs=epochs, batch_size= batch_size, verbose=0,
          callbacks=[learning_rate_reduction]
         )

# Testing model on test data to evaluate
y_pred = np.argmax(model.predict(X_test), axis=-1)

print(accuracy_score(np.argmax(y_test, axis=1),y_pred))
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 200704)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    25,690,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,729,218 (98.15 MB)
#  Trainable params: 25,729,218 (98.15 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 31: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step
# 0.7893939393939394

# %%
X_test
# Out:
# array([[[[0.8       , 0.69411765, 0.61960784],
#          [0.79215686, 0.68235294, 0.62745098],
#          [0.79607843, 0.69019608, 0.62352941],
#          ...,
#          [0.79215686, 0.66666667, 0.58431373],
#          [0.79607843, 0.66666667, 0.59215686],
#          [0.80392157, 0.66666667, 0.59215686]],
#
#         [[0.8       , 0.69411765, 0.62745098],
#          [0.79607843, 0.69019608, 0.62352941],
#          [0.78823529, 0.68235294, 0.61568627],
#          ...,
#          [0.79215686, 0.6627451 , 0.58823529],
#          [0.80392157, 0.65882353, 0.58823529],
#          [0.79607843, 0.65098039, 0.58039216]],
#
#         [[0.79215686, 0.67843137, 0.61568627],
#          [0.79607843, 0.68235294, 0.61960784],
#          [0.79215686, 0.67843137, 0.61568627],
#          ...,
#          [0.79607843, 0.65882353, 0.58431373],
#          [0.79607843, 0.65098039, 0.58039216],
#          [0.79607843, 0.65098039, 0.58039216]],
#
#         ...,
#
#         [[0.78431373, 0.67843137, 0.59607843],
#          [0.8       , 0.69411765, 0.61176471],
#          [0.80392157, 0.70980392, 0.61568627],
#          ...,
#          [0.77254902, 0.6745098 , 0.55294118],
#          [0.77647059, 0.6745098 , 0.56862745],
#          [0.77647059, 0.6745098 , 0.58431373]],
#
#         [[0.78431373, 0.6745098 , 0.61960784],
#          [0.78823529, 0.68627451, 0.62745098],
#          [0.78431373, 0.67843137, 0.61176471],
#          ...,
#          [0.76862745, 0.6627451 , 0.54901961],
#          [0.78039216, 0.6745098 , 0.56862745],
#          [0.78039216, 0.67843137, 0.57254902]],
#
#         [[0.78039216, 0.6745098 , 0.59215686],
#          [0.77647059, 0.6745098 , 0.60784314],
#          [0.77647059, 0.66666667, 0.58039216],
#          ...,
#          [0.77647059, 0.65490196, 0.54509804],
#          [0.77647059, 0.67058824, 0.56470588],
#          [0.78823529, 0.68235294, 0.57647059]]],
#
#
#        [[[0.84313725, 0.49411765, 0.56470588],
#          [0.83921569, 0.49803922, 0.57254902],
#          [0.83529412, 0.48627451, 0.56470588],
#          ...,
#          [0.87058824, 0.56862745, 0.64705882],
#          [0.85882353, 0.54901961, 0.63137255],
#          [0.86666667, 0.54509804, 0.63137255]],
#
#         [[0.85098039, 0.50196078, 0.57254902],
#          [0.84313725, 0.51372549, 0.57647059],
#          [0.84705882, 0.50980392, 0.56078431],
#          ...,
#          [0.8745098 , 0.55686275, 0.63137255],
#          [0.86666667, 0.54901961, 0.62352941],
#          [0.85098039, 0.54901961, 0.61176471]],
#
#         [[0.85882353, 0.50196078, 0.57254902],
#          [0.85882353, 0.51764706, 0.58039216],
#          [0.8627451 , 0.5254902 , 0.57647059],
#          ...,
#          [0.85490196, 0.55294118, 0.62352941],
#          [0.85490196, 0.55294118, 0.61568627],
#          [0.85882353, 0.56862745, 0.63529412]],
#
#         ...,
#
#         [[0.83137255, 0.58431373, 0.61568627],
#          [0.82745098, 0.58431373, 0.58823529],
#          [0.83137255, 0.58039216, 0.58431373],
#          ...,
#          [0.8       , 0.54117647, 0.58823529],
#          [0.8       , 0.55294118, 0.58823529],
#          [0.80784314, 0.56862745, 0.59607843]],
#
#         [[0.81960784, 0.57647059, 0.59607843],
#          [0.83137255, 0.58823529, 0.6       ],
#          [0.84313725, 0.58823529, 0.60392157],
#          ...,
#          [0.80392157, 0.56078431, 0.58039216],
#          [0.80392157, 0.55686275, 0.58823529],
#          [0.80784314, 0.56078431, 0.59215686]],
#
#         [[0.82745098, 0.56862745, 0.58431373],
#          [0.84313725, 0.58431373, 0.6       ],
#          [0.84313725, 0.58039216, 0.60784314],
#          ...,
#          [0.8       , 0.55294118, 0.58431373],
#          [0.80784314, 0.56470588, 0.57647059],
#          [0.8       , 0.55686275, 0.57647059]]],
#
#
#        [[[0.9372549 , 0.63529412, 0.70588235],
#          [0.9254902 , 0.62745098, 0.67843137],
#          [0.94901961, 0.64313725, 0.69803922],
#          ...,
#          [0.95686275, 0.65882353, 0.70588235],
#          [0.96078431, 0.6627451 , 0.70980392],
#          [0.94509804, 0.65882353, 0.70196078]],
#
#         [[0.94901961, 0.63137255, 0.69803922],
#          [0.93333333, 0.63529412, 0.68627451],
#          [0.93333333, 0.63529412, 0.68627451],
#          ...,
#          [0.94117647, 0.65098039, 0.70196078],
#          [0.95294118, 0.65490196, 0.70588235],
#          [0.95294118, 0.65490196, 0.70588235]],
#
#         [[0.93333333, 0.63529412, 0.68627451],
#          [0.92941176, 0.63921569, 0.69019608],
#          [0.9372549 , 0.63137255, 0.69411765],
#          ...,
#          [0.9372549 , 0.65098039, 0.69411765],
#          [0.95294118, 0.65490196, 0.70588235],
#          [0.94901961, 0.65098039, 0.69803922]],
#
#         ...,
#
#         [[0.8745098 , 0.59607843, 0.61176471],
#          [0.87058824, 0.59215686, 0.58431373],
#          [0.86666667, 0.59215686, 0.59215686],
#          ...,
#          [0.8627451 , 0.58431373, 0.6       ],
#          [0.83529412, 0.56078431, 0.56862745],
#          [0.85098039, 0.57647059, 0.57647059]],
#
#         [[0.8627451 , 0.58823529, 0.58823529],
#          [0.8627451 , 0.59607843, 0.59215686],
#          [0.87058824, 0.59607843, 0.58823529],
#          ...,
#          [0.85490196, 0.57254902, 0.57647059],
#          [0.85098039, 0.57647059, 0.57647059],
#          [0.85490196, 0.58039216, 0.58039216]],
#
#         [[0.87058824, 0.58039216, 0.58431373],
#          [0.85882353, 0.58431373, 0.57647059],
#          [0.85490196, 0.58823529, 0.58431373],
#          ...,
#          [0.85490196, 0.57647059, 0.56078431],
#          [0.84313725, 0.57254902, 0.55294118],
#          [0.84705882, 0.56862745, 0.56078431]]],
#
#
#        ...,
#
#
#        [[[0.85490196, 0.84705882, 0.75686275],
#          [0.8627451 , 0.85490196, 0.77254902],
#          [0.86666667, 0.85882353, 0.77647059],
#          ...,
#          [0.35294118, 0.25490196, 0.23529412],
#          [0.37647059, 0.27843137, 0.25882353],
#          [0.39215686, 0.27843137, 0.2627451 ]],
#
#         [[0.85490196, 0.84705882, 0.76470588],
#          [0.8627451 , 0.85490196, 0.77254902],
#          [0.86666667, 0.85882353, 0.77647059],
#          ...,
#          [0.34901961, 0.25490196, 0.23921569],
#          [0.37254902, 0.27843137, 0.27058824],
#          [0.38823529, 0.28627451, 0.28235294]],
#
#         [[0.85490196, 0.84705882, 0.76470588],
#          [0.8627451 , 0.85490196, 0.77254902],
#          [0.86666667, 0.85882353, 0.77647059],
#          ...,
#          [0.36862745, 0.28235294, 0.29019608],
#          [0.38823529, 0.30196078, 0.30980392],
#          [0.37647059, 0.29019608, 0.29803922]],
#
#         ...,
#
#         [[0.84313725, 0.81960784, 0.75686275],
#          [0.84313725, 0.81960784, 0.75686275],
#          [0.84313725, 0.81960784, 0.75686275],
#          ...,
#          [0.40784314, 0.19607843, 0.18823529],
#          [0.36470588, 0.14901961, 0.12156863],
#          [0.34509804, 0.12156863, 0.07843137]],
#
#         [[0.84313725, 0.81960784, 0.75686275],
#          [0.84313725, 0.81960784, 0.75686275],
#          [0.84313725, 0.81960784, 0.75686275],
#          ...,
#          [0.41960784, 0.20784314, 0.16862745],
#          [0.37647059, 0.15686275, 0.09803922],
#          [0.36862745, 0.14509804, 0.07058824]],
#
#         [[0.83921569, 0.81568627, 0.75294118],
#          [0.84313725, 0.81960784, 0.75686275],
#          [0.84313725, 0.81960784, 0.75686275],
#          ...,
#          [0.42745098, 0.20784314, 0.14117647],
#          [0.38431373, 0.16078431, 0.08235294],
#          [0.43137255, 0.20392157, 0.10980392]]],
#
#
#        [[[0.96078431, 0.64705882, 0.61960784],
#          [0.96078431, 0.64313725, 0.62745098],
#          [0.96470588, 0.63137255, 0.60392157],
#          ...,
#          [0.94901961, 0.59607843, 0.56078431],
#          [0.95686275, 0.59607843, 0.54509804],
#          [0.96470588, 0.60392157, 0.55294118]],
#
#         [[0.96078431, 0.64313725, 0.62745098],
#          [0.96078431, 0.64705882, 0.61960784],
#          [0.96470588, 0.63137255, 0.60392157],
#          ...,
#          [0.94901961, 0.58039216, 0.54901961],
#          [0.94901961, 0.58039216, 0.54117647],
#          [0.95686275, 0.59607843, 0.54509804]],
#
#         [[0.96078431, 0.64313725, 0.62745098],
#          [0.96078431, 0.64705882, 0.61960784],
#          [0.96470588, 0.63137255, 0.61176471],
#          ...,
#          [0.9372549 , 0.58431373, 0.54901961],
#          [0.94509804, 0.59215686, 0.54901961],
#          [0.95686275, 0.58823529, 0.54901961]],
#
#         ...,
#
#         [[0.91764706, 0.57254902, 0.51764706],
#          [0.92156863, 0.58039216, 0.51372549],
#          [0.92941176, 0.58431373, 0.52941176],
#          ...,
#          [0.90196078, 0.60784314, 0.51764706],
#          [0.91372549, 0.61176471, 0.53333333],
#          [0.91764706, 0.61568627, 0.54509804]],
#
#         [[0.90980392, 0.56470588, 0.50980392],
#          [0.92941176, 0.57647059, 0.53333333],
#          [0.9372549 , 0.59215686, 0.54509804],
#          ...,
#          [0.89019608, 0.59607843, 0.51372549],
#          [0.89803922, 0.59607843, 0.5254902 ],
#          [0.90980392, 0.60392157, 0.5254902 ]],
#
#         [[0.91764706, 0.57254902, 0.51764706],
#          [0.90588235, 0.56862745, 0.51764706],
#          [0.91764706, 0.58039216, 0.52941176],
#          ...,
#          [0.88627451, 0.57647059, 0.50980392],
#          [0.91372549, 0.60784314, 0.52941176],
#          [0.90588235, 0.60392157, 0.5254902 ]]],
#
#
#        [[[0.61960784, 0.4627451 , 0.49803922],
#          [0.62352941, 0.46666667, 0.49803922],
#          [0.62352941, 0.46666667, 0.49803922],
#          ...,
#          [0.68627451, 0.54509804, 0.56078431],
#          [0.67843137, 0.5372549 , 0.5372549 ],
#          [0.67058824, 0.52941176, 0.52941176]],
#
#         [[0.62745098, 0.47058824, 0.50196078],
#          [0.63137255, 0.4745098 , 0.50588235],
#          [0.63137255, 0.49019608, 0.50588235],
#          ...,
#          [0.68627451, 0.54509804, 0.56078431],
#          [0.67843137, 0.5372549 , 0.54509804],
#          [0.66666667, 0.5254902 , 0.53333333]],
#
#         [[0.62745098, 0.48235294, 0.50980392],
#          [0.63529412, 0.48235294, 0.50196078],
#          [0.64313725, 0.49019608, 0.50980392],
#          ...,
#          [0.69411765, 0.55294118, 0.56862745],
#          [0.67058824, 0.52941176, 0.5372549 ],
#          [0.65490196, 0.51372549, 0.51372549]],
#
#         ...,
#
#         [[0.60392157, 0.44705882, 0.44705882],
#          [0.60392157, 0.44313725, 0.45882353],
#          [0.60392157, 0.44313725, 0.46666667],
#          ...,
#          [0.68235294, 0.5254902 , 0.5254902 ],
#          [0.6745098 , 0.54117647, 0.54509804],
#          [0.68627451, 0.54901961, 0.57254902]],
#
#         [[0.6       , 0.43921569, 0.45490196],
#          [0.60392157, 0.44313725, 0.46666667],
#          [0.6       , 0.43921569, 0.4627451 ],
#          ...,
#          [0.6745098 , 0.5372549 , 0.52156863],
#          [0.68235294, 0.54509804, 0.56078431],
#          [0.68627451, 0.54901961, 0.56470588]],
#
#         [[0.60392157, 0.43529412, 0.47058824],
#          [0.60784314, 0.44705882, 0.47058824],
#          [0.60392157, 0.44313725, 0.46666667],
#          ...,
#          [0.67843137, 0.5372549 , 0.5372549 ],
#          [0.68235294, 0.54117647, 0.55686275],
#          [0.68627451, 0.54901961, 0.57254902]]]])

# %%
background = X_train[np.random.choice(X_train.shape[0], 100, replace=False)]

# explain predictions of the model on three images
e = shap.DeepExplainer(model, background)
# ...or pass tensors directly
# e = shap.DeepExplainer((model.layers[0].input, model.layers[-1].output), background)
shap_values = e.shap_values(X_test[0:5])
# Out:
# C:\Users\kopal\anaconda\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\kopal\anaconda\Lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: keras_tensor. Received: the structure of inputs=['*']
#   warnings.warn(

# %%
shap.image_plot(shap_values, -X_test[0:5])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
explainer = shap.Explainer(model, background)

# Compute SHAP values for the test set
shap_values = explainer(X_test)

# If SHAP values are an Explanation object, extract the values
if isinstance(shap_values, shap.Explanation):
    shap_values = shap_values.values

# Force plot for the first observation with matplotlib
# The expected_value is the model's expected output for the dataset
# The shap_values[0] represents the SHAP values for the first observation
# X_test.iloc[0, :] is the corresponding feature values for the first observation
shap.force_plot(explainer.expected_value, shap_values[0], X_test.iloc[0, :], matplotlib=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[135], line 4
#       1 explainer = shap.Explainer(model, background)
#       3 # Compute SHAP values for the test set
# ----> 4 shap_values = explainer(X_test)
#       6 # If SHAP values are an Explanation object, extract the values
#       7 if isinstance(shap_values, shap.Explanation):
#
# File ~\anaconda\Lib\site-packages\shap\explainers\_permutation.py:77, in PermutationExplainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args)
#      74 def __call__(self, *args, max_evals=500, main_effects=False, error_bounds=False, batch_size="auto",
#      75              outputs=None, silent=False):
#      76     """Explain the output of the model on the given arguments."""
# ---> 77     return super().__call__(
#      78         *args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds, batch_size=batch_size,
#      79         outputs=outputs, silent=silent
#      80     )
#
# File ~\anaconda\Lib\site-packages\shap\explainers\_explainer.py:266, in Explainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args, **kwargs)
#     264     feature_names = [[] for _ in range(len(args))]
#     265 for row_args in show_progress(zip(*args), num_rows, self.__class__.__name__+" explainer", silent):
# --> 266     row_result = self.explain_row(
#     267         *row_args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds,
#     268         batch_size=batch_size, outputs=outputs, silent=silent, **kwargs
#     269     )
#     270     values.append(row_result.get("values", None))
#     271     output_indices.append(row_result.get("output_indices", None))
#
# File ~\anaconda\Lib\site-packages\shap\explainers\_permutation.py:133, in PermutationExplainer.explain_row(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *row_args)
#     130     i += 1
#     132 # evaluate the masked model
# --> 133 outputs = fm(masks, zero_index=0, batch_size=batch_size)
#     135 if row_values is None:
#     136     row_values = np.zeros((len(fm),) + outputs.shape[1:])
#
# File ~\anaconda\Lib\site-packages\shap\utils\_masked_model.py:67, in MaskedModel.__call__(self, masks, zero_index, batch_size)
#      65         full_masks = np.zeros((int(np.sum(masks >= 0)), self._masker_cols), dtype=bool)
#      66         _convert_delta_mask_to_full(masks, full_masks)
# ---> 67         return self._full_masking_call(full_masks, zero_index=zero_index, batch_size=batch_size)
#      69 else:
#      70     return self._full_masking_call(masks, batch_size=batch_size)
#
# File ~\anaconda\Lib\site-packages\shap\utils\_masked_model.py:96, in MaskedModel._full_masking_call(self, masks, zero_index, batch_size)
#      94     masked_inputs = self.masker(delta_ind, *self.args).copy()
#      95 else:
# ---> 96     masked_inputs = self.masker(mask, *self.args)
#      98 # get a copy that won't get overwritten by the next iteration
#      99 if not getattr(self.masker, "immutable_outputs", False):
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
images = []
for i, folder in enumerate([benign_dir, malignant_dir]):
    for img_name in os.listdir(folder)[:10]:  # Load first 10 images from each class
        img_path = os.path.join(folder, img_name)
        img_array = preprocess_image(img_path)
        images.append(img_array)

# Convert to numpy array and ensure dimensions are (N, H, W, C)
images = np.array(images)

# %%
background = images[:10]

# %%
import shap

# Assuming `model` is your trained Keras model
explainer = shap.DeepExplainer(model, background)
shap_values = explainer.shap_values(images)

# Visualize SHAP values for the images
shap.image_plot(shap_values, images)
# Out:
# C:\Users\kopal\anaconda\Lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# C:\Users\kopal\anaconda\Lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: keras_tensor. Received: the structure of inputs=['*']
#   warnings.warn(
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model_json = model.to_json()

with open("model.json", "w") as json_file:
    json_file.write(model_json)
    
# serialize weights to HDF5
model.save_weights("model.weights.h5")
print("Saved model to disk")

# Clear memory, because of memory overload
del model
K.clear_session()
# Out:
# Saved model to disk

# %%
input_shape = (224,224,3)
lr = 1e-5
epochs = 50
batch_size = 64

model = ResNet50(include_top=True,
                 weights= None,
                 input_tensor=None,
                 input_shape=input_shape,
                 pooling='avg',
                 classes=2)

model.compile(optimizer = Adam(lr) ,
              loss = "binary_crossentropy", 
              metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, validation_split=0.2,
                    epochs= epochs, batch_size= batch_size, verbose=2, 
                    callbacks=[learning_rate_reduction]
                   )
# Out:
# Epoch 1/50
# 33/33 - 270s - 8s/step - accuracy: 0.6591 - loss: 0.6878 - val_accuracy: 0.5360 - val_loss: 0.6996 - learning_rate: 1.0000e-05
# Epoch 2/50
# 33/33 - 258s - 8s/step - accuracy: 0.7748 - loss: 0.4967 - val_accuracy: 0.5360 - val_loss: 0.7175 - learning_rate: 1.0000e-05
# Epoch 3/50
# 33/33 - 250s - 8s/step - accuracy: 0.7914 - loss: 0.4331 - val_accuracy: 0.5360 - val_loss: 0.7836 - learning_rate: 1.0000e-05
# Epoch 4/50
# 33/33 - 246s - 7s/step - accuracy: 0.8122 - loss: 0.3972 - val_accuracy: 0.5360 - val_loss: 0.9379 - learning_rate: 1.0000e-05
# Epoch 5/50
# 33/33 - 253s - 8s/step - accuracy: 0.8170 - loss: 0.3862 - val_accuracy: 0.5360 - val_loss: 1.2075 - learning_rate: 1.0000e-05
# Epoch 6/50
# 33/33 - 253s - 8s/step - accuracy: 0.8317 - loss: 0.3649 - val_accuracy: 0.5360 - val_loss: 1.4039 - learning_rate: 1.0000e-05
# Epoch 7/50
# 33/33 - 254s - 8s/step - accuracy: 0.8350 - loss: 0.3509 - val_accuracy: 0.5360 - val_loss: 1.3936 - learning_rate: 1.0000e-05
# Epoch 8/50
# 33/33 - 257s - 8s/step - accuracy: 0.8397 - loss: 0.3354 - val_accuracy: 0.5360 - val_loss: 1.6241 - learning_rate: 1.0000e-05
# Epoch 9/50
# 33/33 - 256s - 8s/step - accuracy: 0.8573 - loss: 0.3206 - val_accuracy: 0.5360 - val_loss: 1.4594 - learning_rate: 1.0000e-05
# Epoch 10/50
# 33/33 - 258s - 8s/step - accuracy: 0.8601 - loss: 0.3167 - val_accuracy: 0.5379 - val_loss: 1.2809 - learning_rate: 1.0000e-05
# Epoch 11/50
# 33/33 - 261s - 8s/step - accuracy: 0.8715 - loss: 0.2894 - val_accuracy: 0.5663 - val_loss: 1.0198 - learning_rate: 1.0000e-05
# Epoch 12/50
# 33/33 - 259s - 8s/step - accuracy: 0.8767 - loss: 0.2815 - val_accuracy: 0.5587 - val_loss: 1.1528 - learning_rate: 1.0000e-05
# Epoch 13/50
# 33/33 - 259s - 8s/step - accuracy: 0.8796 - loss: 0.2748 - val_accuracy: 0.5303 - val_loss: 1.1449 - learning_rate: 1.0000e-05
# Epoch 14/50
# 33/33 - 260s - 8s/step - accuracy: 0.8838 - loss: 0.2657 - val_accuracy: 0.5303 - val_loss: 0.9509 - learning_rate: 1.0000e-05
# Epoch 15/50
# 33/33 - 295s - 9s/step - accuracy: 0.8862 - loss: 0.2505 - val_accuracy: 0.5511 - val_loss: 1.0506 - learning_rate: 1.0000e-05
# Epoch 16/50
# 33/33 - 469s - 14s/step - accuracy: 0.8943 - loss: 0.2374 - val_accuracy: 0.5814 - val_loss: 0.9253 - learning_rate: 1.0000e-05
# Epoch 17/50
# 33/33 - 469s - 14s/step - accuracy: 0.9071 - loss: 0.2225 - val_accuracy: 0.6117 - val_loss: 0.9220 - learning_rate: 1.0000e-05
# Epoch 18/50
# 33/33 - 478s - 14s/step - accuracy: 0.9118 - loss: 0.2083 - val_accuracy: 0.6648 - val_loss: 0.7064 - learning_rate: 1.0000e-05
# Epoch 19/50
# 33/33 - 487s - 15s/step - accuracy: 0.9033 - loss: 0.2314 - val_accuracy: 0.7008 - val_loss: 0.6937 - learning_rate: 1.0000e-05
# Epoch 20/50
# 33/33 - 462s - 14s/step - accuracy: 0.9037 - loss: 0.2123 - val_accuracy: 0.7576 - val_loss: 0.5680 - learning_rate: 1.0000e-05
# Epoch 21/50
# 33/33 - 434s - 13s/step - accuracy: 0.9090 - loss: 0.2046 - val_accuracy: 0.7254 - val_loss: 0.5912 - learning_rate: 1.0000e-05
# Epoch 22/50
# 33/33 - 450s - 14s/step - accuracy: 0.9327 - loss: 0.1744 - val_accuracy: 0.7917 - val_loss: 0.6259 - learning_rate: 1.0000e-05
# Epoch 23/50
# 33/33 - 460s - 14s/step - accuracy: 0.9275 - loss: 0.1772 - val_accuracy: 0.7443 - val_loss: 0.6794 - learning_rate: 1.0000e-05
# Epoch 24/50
# 33/33 - 456s - 14s/step - accuracy: 0.9246 - loss: 0.1686 - val_accuracy: 0.7311 - val_loss: 0.7910 - learning_rate: 1.0000e-05
# Epoch 25/50
# 33/33 - 476s - 14s/step - accuracy: 0.9331 - loss: 0.1545 - val_accuracy: 0.6610 - val_loss: 1.1129 - learning_rate: 1.0000e-05
# Epoch 26/50
# 33/33 - 467s - 14s/step - accuracy: 0.9398 - loss: 0.1453 - val_accuracy: 0.8049 - val_loss: 0.7543 - learning_rate: 1.0000e-05
# Epoch 27/50
# 33/33 - 883s - 27s/step - accuracy: 0.9464 - loss: 0.1347 - val_accuracy: 0.7746 - val_loss: 0.6993 - learning_rate: 1.0000e-05
# Epoch 28/50
# 33/33 - 465s - 14s/step - accuracy: 0.9450 - loss: 0.1267 - val_accuracy: 0.8087 - val_loss: 0.6040 - learning_rate: 1.0000e-05
# Epoch 29/50
# 33/33 - 494s - 15s/step - accuracy: 0.9478 - loss: 0.1333 - val_accuracy: 0.8125 - val_loss: 0.7190 - learning_rate: 1.0000e-05
# Epoch 30/50
# 33/33 - 476s - 14s/step - accuracy: 0.9450 - loss: 0.1348 - val_accuracy: 0.7822 - val_loss: 0.8303 - learning_rate: 1.0000e-05
# Epoch 31/50
# 33/33 - 474s - 14s/step - accuracy: 0.9559 - loss: 0.1216 - val_accuracy: 0.8163 - val_loss: 0.5150 - learning_rate: 1.0000e-05
# Epoch 32/50
# 33/33 - 463s - 14s/step - accuracy: 0.9654 - loss: 0.1021 - val_accuracy: 0.7822 - val_loss: 0.6651 - learning_rate: 1.0000e-05
# Epoch 33/50
# 33/33 - 468s - 14s/step - accuracy: 0.9535 - loss: 0.1214 - val_accuracy: 0.7652 - val_loss: 0.7288 - learning_rate: 1.0000e-05
# Epoch 34/50
# 33/33 - 473s - 14s/step - accuracy: 0.9507 - loss: 0.1212 - val_accuracy: 0.8220 - val_loss: 0.8016 - learning_rate: 1.0000e-05
# Epoch 35/50
# 33/33 - 464s - 14s/step - accuracy: 0.9431 - loss: 0.1360 - val_accuracy: 0.8163 - val_loss: 0.7869 - learning_rate: 1.0000e-05
# Epoch 36/50
# 33/33 - 477s - 14s/step - accuracy: 0.9659 - loss: 0.0877 - val_accuracy: 0.8144 - val_loss: 0.6420 - learning_rate: 1.0000e-05
# Epoch 37/50
# 33/33 - 370s - 11s/step - accuracy: 0.9668 - loss: 0.0853 - val_accuracy: 0.8352 - val_loss: 0.5703 - learning_rate: 1.0000e-05
# Epoch 38/50
# 33/33 - 254s - 8s/step - accuracy: 0.9692 - loss: 0.0787 - val_accuracy: 0.8011 - val_loss: 0.6903 - learning_rate: 1.0000e-05
# Epoch 39/50
# 33/33 - 251s - 8s/step - accuracy: 0.9701 - loss: 0.0768 - val_accuracy: 0.7841 - val_loss: 0.7605 - learning_rate: 1.0000e-05
# Epoch 40/50
# 33/33 - 252s - 8s/step - accuracy: 0.9692 - loss: 0.0825 - val_accuracy: 0.7140 - val_loss: 1.1319 - learning_rate: 1.0000e-05
# Epoch 41/50
# 33/33 - 252s - 8s/step - accuracy: 0.9701 - loss: 0.0788 - val_accuracy: 0.8087 - val_loss: 0.7017 - learning_rate: 1.0000e-05
# Epoch 42/50
# 33/33 - 252s - 8s/step - accuracy: 0.9753 - loss: 0.0619 - val_accuracy: 0.7879 - val_loss: 0.7995 - learning_rate: 1.0000e-05
# Epoch 43/50
# 33/33 - 252s - 8s/step - accuracy: 0.9663 - loss: 0.0834 - val_accuracy: 0.8125 - val_loss: 0.6415 - learning_rate: 1.0000e-05
# Epoch 44/50
# 33/33 - 251s - 8s/step - accuracy: 0.9701 - loss: 0.0792 - val_accuracy: 0.8011 - val_loss: 0.8030 - learning_rate: 1.0000e-05
# Epoch 45/50
# 33/33 - 250s - 8s/step - accuracy: 0.9739 - loss: 0.0677 - val_accuracy: 0.8125 - val_loss: 0.6129 - learning_rate: 1.0000e-05
# Epoch 46/50
# 33/33 - 252s - 8s/step - accuracy: 0.9606 - loss: 0.1145 - val_accuracy: 0.7822 - val_loss: 0.6656 - learning_rate: 1.0000e-05
# Epoch 47/50
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 33/33 - 242s - 7s/step - accuracy: 0.9692 - loss: 0.0803 - val_accuracy: 0.8163 - val_loss: 0.5716 - learning_rate: 1.0000e-05
# Epoch 48/50
# 33/33 - 412s - 12s/step - accuracy: 0.9720 - loss: 0.0751 - val_accuracy: 0.8314 - val_loss: 0.5493 - learning_rate: 5.0000e-06
# Epoch 49/50
# 33/33 - 481s - 15s/step - accuracy: 0.9810 - loss: 0.0604 - val_accuracy: 0.8466 - val_loss: 0.5705 - learning_rate: 5.0000e-06
# Epoch 50/50
# 33/33 - 555s - 17s/step - accuracy: 0.9796 - loss: 0.0548 - val_accuracy: 0.8144 - val_loss: 0.6042 - learning_rate: 5.0000e-06

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss', 'learning_rate'])

# %%
model.fit(X_train, y_train,
          epochs=epochs, batch_size= epochs, verbose=0,
          callbacks=[learning_rate_reduction]
         )
# Out:
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.

# %%
y_pred = model.predict(X_test)
print(accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1)))

# save model
# serialize model to JSON
resnet50_json = model.to_json()

with open("resnet50.json", "w") as json_file:
    json_file.write(resnet50_json)
    
# serialize weights to HDF5
model.save_weights("resnet50.weights.h5")
print("Saved model to disk")
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step
# 0.8242424242424242
# Saved model to disk
